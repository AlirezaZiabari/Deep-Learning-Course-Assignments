# %% [markdown]
# # CE-40959: Deep Learning

# %% [markdown]
# # HW3. Part 3. CNN on CIFAR (20 + 10 points)

# %% [markdown]
# ### Deadline:   16 Farvardin

# %% [markdown]
# In this problem, we will train a CNN on CIFAR-10 database. Next, we will go through the network and visualize its layers to see what is happening there. Then, we use the trained model in a Transfer Learning approach to classifying the CIFAR-100 database.

# %% [markdown]
# Let's start with loading data. First load the data by runing the code below:

# %%
# from load_data import load_cifar10 #this function provided in the attached file loads the data of CIFAR10 database
from keras.datasets import cifar10

def load_cifar10_data():
    dataset_dir = 'data/cifar-10-batches-py'
    
#     X_train, y_train, X_test, y_test = load_cifar10(dataset_dir)
    (X_train, y_train), (X_test, y_test) = cifar10.load_data()
    X_train, X_val = X_train[:45000], X_train[45000:]
    y_train, y_val = y_train[:45000], y_train[45000:]
    
    return X_train, y_train, X_val, y_val, X_test, y_test
# Out:
# Using TensorFlow backend.

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10_data()

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_val shape:', X_val.shape)
print('y_val shape:', y_val.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)

import matplotlib.pyplot as plt
plt.imshow(X_train[1])#represnting a sample data from CIFAR-10
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 23s 0us/step
# X_train shape: (45000, 32, 32, 3)
# y_train shape: (45000, 1)
# X_val shape: (5000, 32, 32, 3)
# y_val shape: (5000, 1)
# X_test shape: (10000, 32, 32, 3)
# y_test shape: (10000, 1)

# %% [markdown]
# By successfully runing the above code, you have loaded the data and also you can see a sample data from CIFAR-10.

# %% [markdown]
# The below code will convert the labels to one-hot codes which will be later used for the classification.

# %%
import numpy as np

from sklearn.preprocessing import OneHotEncoder # this function is used to prepare one-hot encoded labels
encoder = OneHotEncoder(sparse=False)

encoder.fit(y_train)#this line will fit 'encoder' to encode the labels

y_train_onehot = encoder.transform(y_train)# encoding train labels (one-hot coding)
y_val_onehot   = encoder.transform(y_val)  # encoding train labels (one-hot coding)
y_test_onehot  = encoder.transform(y_test) # encoding test  labels (one-hot coding)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The function below is for converting data to several batches which we will use in training.

# %%
def make_batches(x, y, batch_size):
    n = len(y)
    steps = n // batch_size
    if n % batch_size != 0:
        steps += 1
    x_batches = np.array_split(x, steps)
    y_batches = np.array_split(y, steps)
    return x_batches, y_batches

# %% [markdown]
# ## Part1: Trainig a CNN (15 pts.)

# %% [markdown]
# In this part, we are going to train a Convolutional Neural Network (CNN) with the below structure:

# %% [markdown]
# 1. 16 * conv(5,5), activation function =ReLU
# 2. 16 * conv(5,5), activation function =ReLU
# 3. Max-pooling(3,3), stride=(2,2)
# 4. 32 * conv(5,5), activation function =ReLU
# 5. 32 * conv(5,5), activation function =ReLU
# 6. Max-pooling(3,3), stride=(2,2)
# 7. 64 * conv(5,5), activation function =ReLU
# 8. FC(128), activation function =ReLU
# 9. FC(128), activation function =ReLU
# 10. FC(10), activation function =softmax

# %% [markdown]
# Let's go to implement the model in the below box. Note that using **tf.layers** is **NOT ALLOWED** in this homework.

# %%
import tensorflow as tf

x = tf.placeholder(tf.float32, [None, 32, 32, 3]) # placeholder for input data
y = tf.placeholder(tf.float32, [None, 10])# placeholder for labels (one-hot encoded)

# Define the needed Variables here:
W_conv1 = tf.Variable(tf.truncated_normal(shape=[5, 5, 3, 16], mean = 0.0, stddev = 0.01),name="W_conv1")
B_conv1 = tf.Variable(tf.constant(0.01, shape=[16]),name="B_conv1")
W_conv2 = tf.Variable(tf.truncated_normal(shape=[5, 5, 16, 16], mean = 0.0, stddev = 0.01),name="W_conv2")
B_conv2 = tf.Variable(tf.constant(0.01, shape=[16]),name="B_conv2")
W_conv3 = tf.Variable(tf.truncated_normal(shape=[5, 5, 16, 32], mean = 0.0, stddev = 0.01),name="W_conv3")
B_conv3 = tf.Variable(tf.constant(0.01, shape=[32]),name="B_conv3")
W_conv4 = tf.Variable(tf.truncated_normal(shape=[5, 5, 32, 32], mean = 0.0, stddev = 0.01),name="W_conv4")
B_conv4 = tf.Variable(tf.constant(0.01, shape=[32]),name="B_conv4")
W_conv5 = tf.Variable(tf.truncated_normal(shape=[5, 5, 32, 64], mean = 0.0, stddev = 0.01),name="W_conv5")
B_conv5 = tf.Variable(tf.constant(0.01, shape=[64]),name="B_conv5")
# Define the layers here:
conv1 = tf.nn.conv2d(x, W_conv1, strides=[1, 1, 1, 1], padding='SAME') + B_conv1
conv1_relu = tf.nn.relu(conv1)
conv2 = tf.nn.conv2d(conv1_relu, W_conv2, strides=[1, 1, 1, 1], padding='SAME') + B_conv2
conv2_relu = tf.nn.relu(conv2)
pooling1 = tf.nn.max_pool(conv2_relu, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME')
conv3 = tf.nn.conv2d(pooling1, W_conv3, strides=[1, 1, 1, 1], padding='SAME') + B_conv3
conv3_relu = tf.nn.relu(conv3)
conv4 = tf.nn.conv2d(conv3_relu, W_conv4, strides=[1, 1, 1, 1], padding='SAME') + B_conv4
conv4_relu = tf.nn.relu(conv4)
pooling2 = tf.nn.max_pool(conv4_relu, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME')
conv5 = tf.nn.conv2d(pooling2, W_conv5, strides=[1, 1, 1, 1], padding='SAME') + B_conv5
conv5_relu = tf.nn.relu(conv5)   

flat_conv5 = tf.reshape(conv5_relu, [-1, conv5.shape[1]*conv5.shape[2]*conv5.shape[3]])
W_FC1 = tf.Variable(tf.truncated_normal(shape=[tf.cast(flat_conv5.shape[1],tf.int32), 128], mean = 0.0, stddev = 0.1),name="W_FC1")
B_FC1 = tf.Variable(tf.constant(0.01, shape=[128]),name="B_FC1")
W_FC2 = tf.Variable(tf.truncated_normal(shape=[128, 128], mean = 0.0, stddev = 0.01),name="W_FC2")
B_FC2 = tf.Variable(tf.constant(0.01, shape=[128]),name="B_FC2")
W_FC3 = tf.Variable(tf.truncated_normal(shape=[128, 10], mean = 0.0, stddev = 0.01),name="W_FC3")
B_FC3 = tf.Variable(tf.constant(0.01, shape=[10]),name="B_FC3")

FC1 = tf.matmul(flat_conv5, W_FC1) + B_FC1
FC1_relu = tf.nn.relu(FC1)
FC2 = tf.matmul(FC1_relu, W_FC2) + B_FC2
FC2_relu = tf.nn.relu(FC2)
FC3 = tf.matmul(FC2_relu, W_FC3) + B_FC3
y_hat = tf.nn.softmax(FC3)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# Now you need to define an optimizer. You are free to use any optimizer. You can change optimizer or learning rate if you want :)

# %%
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=FC3, labels=y))

lr = 5e-5 # learning rate
optimizer = tf.train.AdamOptimizer(learning_rate=lr)
trainer = optimizer.minimize(cross_entropy)

correct_preds = tf.argmax(y, axis=1)
accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(y_hat, axis=1), correct_preds),tf.float64))

# %% [markdown]
# You can go for the rest of the job, handle the Session and go for training.
# You can use tensorboard or the code provided in the next box to plot for loss and accuracy of training and validation data.
# You are expected to achieve at least 60% accuracy on the test data after the training process. Good Luck! ;)

# %%
########## Training ##########
batch_size = 64 
x_train_batches, y_train_batches = make_batches(X_train, y_train_onehot, batch_size)
epochs = 50 
N_Batches = len(x_train_batches)

train_acc  = np.zeros(epochs)
train_loss = np.zeros(epochs)
val_acc  = np.zeros(epochs)
val_loss = np.zeros(epochs)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for epoch in range(epochs):
        print()
        print("*" * 10, "Epoch %3i"%epoch, "*" * 10)

        batch_acc = np.zeros(N_Batches)
        batch_loss = np.zeros(N_Batches)
        for n in range(N_Batches):
            _, batch_acc[n], batch_loss[n] = sess.run([trainer, accuracy, cross_entropy],
                                                      {x: x_train_batches[n], y: y_train_batches[n]})
            #print("Batch %3d/%d: Acc:%0.4f , Loss:%0.4f"%(n, N_Batches, batch_acc[n], batch_loss[n]))

        train_acc[epoch] = np.mean(batch_acc)
        train_loss[epoch] = np.mean(batch_loss)
        print("Train:\t\tAccuracy= %0.4f \tLoss= %0.4f"%(train_acc[epoch], train_loss[epoch]))

        val_acc[epoch], val_loss[epoch] = sess.run([accuracy, cross_entropy],
                                                   {x: X_val, y: y_val_onehot})
        print("Validation:\tAccuracy= %0.4f \tLoss= %0.4f"%(val_acc[epoch], val_loss[epoch]))

    test_acc, test_loss = sess.run([accuracy, cross_entropy],{x: X_test, y: y_test_onehot})
    print("Test:\tAccuracy= %0.4f \tLoss= %0.4f"%(test_acc, test_loss))
# Out:
# ********** Epoch   0 **********
# Train:		Accuracy= 0.2490 	Loss= 2.0042
# Validation:	Accuracy= 0.2890 	Loss= 1.9076
#
# ********** Epoch   1 **********
# Train:		Accuracy= 0.3324 	Loss= 1.8078
# Validation:	Accuracy= 0.3522 	Loss= 1.7398
#
# ********** Epoch   2 **********
# Train:		Accuracy= 0.3846 	Loss= 1.6670
# Validation:	Accuracy= 0.3870 	Loss= 1.6665
#
# ********** Epoch   3 **********
# Train:		Accuracy= 0.4170 	Loss= 1.5806
# Validation:	Accuracy= 0.4238 	Loss= 1.5823
#
# ********** Epoch   4 **********
# Train:		Accuracy= 0.4459 	Loss= 1.5155
# Validation:	Accuracy= 0.4496 	Loss= 1.5199
#
# ********** Epoch   5 **********
# Train:		Accuracy= 0.4690 	Loss= 1.4626
# Validation:	Accuracy= 0.4718 	Loss= 1.4666
#
# ********** Epoch   6 **********
# Train:		Accuracy= 0.4865 	Loss= 1.4173
# Validation:	Accuracy= 0.4916 	Loss= 1.4171
#
# ********** Epoch   7 **********
# Train:		Accuracy= 0.5042 	Loss= 1.3743
# Validation:	Accuracy= 0.5092 	Loss= 1.3704
#
# ********** Epoch   8 **********
# Train:		Accuracy= 0.5197 	Loss= 1.3337
# Validation:	Accuracy= 0.5202 	Loss= 1.3294
#
# ********** Epoch   9 **********
# Train:		Accuracy= 0.5338 	Loss= 1.2963
# Validation:	Accuracy= 0.5406 	Loss= 1.2826
#
# ********** Epoch  10 **********
# Train:		Accuracy= 0.5478 	Loss= 1.2626
# Validation:	Accuracy= 0.5546 	Loss= 1.2424
#
# ********** Epoch  11 **********
# Train:		Accuracy= 0.5605 	Loss= 1.2296
# Validation:	Accuracy= 0.5670 	Loss= 1.2145
#
# ********** Epoch  12 **********
# Train:		Accuracy= 0.5724 	Loss= 1.1987
# Validation:	Accuracy= 0.5812 	Loss= 1.1870
#
# ********** Epoch  13 **********
# Train:		Accuracy= 0.5835 	Loss= 1.1696
# Validation:	Accuracy= 0.5898 	Loss= 1.1642
#
# ********** Epoch  14 **********
# Train:		Accuracy= 0.5939 	Loss= 1.1414
# Validation:	Accuracy= 0.6004 	Loss= 1.1397
#
# ********** Epoch  15 **********
# Train:		Accuracy= 0.6023 	Loss= 1.1143
# Validation:	Accuracy= 0.6074 	Loss= 1.1152
#
# ********** Epoch  16 **********
# Train:		Accuracy= 0.6128 	Loss= 1.0879
# Validation:	Accuracy= 0.6162 	Loss= 1.0925
#
# ********** Epoch  17 **********
# Train:		Accuracy= 0.6228 	Loss= 1.0619
# Validation:	Accuracy= 0.6270 	Loss= 1.0752
#
# ********** Epoch  18 **********
# Train:		Accuracy= 0.6331 	Loss= 1.0373
# Validation:	Accuracy= 0.6340 	Loss= 1.0577
#
# ********** Epoch  19 **********
# Train:		Accuracy= 0.6424 	Loss= 1.0140
# Validation:	Accuracy= 0.6396 	Loss= 1.0385
#
# ********** Epoch  20 **********
# Train:		Accuracy= 0.6510 	Loss= 0.9902
# Validation:	Accuracy= 0.6460 	Loss= 1.0236
#
# ********** Epoch  21 **********
# Train:		Accuracy= 0.6591 	Loss= 0.9674
# Validation:	Accuracy= 0.6486 	Loss= 1.0071
#
# ********** Epoch  22 **********
# Train:		Accuracy= 0.6660 	Loss= 0.9457
# Validation:	Accuracy= 0.6524 	Loss= 1.0010
#
# ********** Epoch  23 **********
# Train:		Accuracy= 0.6734 	Loss= 0.9256
# Validation:	Accuracy= 0.6504 	Loss= 1.0014
#
# ********** Epoch  24 **********
# Train:		Accuracy= 0.6801 	Loss= 0.9060
# Validation:	Accuracy= 0.6498 	Loss= 1.0145
#
# ********** Epoch  25 **********
# Train:		Accuracy= 0.6865 	Loss= 0.8879
# Validation:	Accuracy= 0.6522 	Loss= 1.0084
#
# ********** Epoch  26 **********
# Train:		Accuracy= 0.6924 	Loss= 0.8692
# Validation:	Accuracy= 0.6644 	Loss= 0.9783
#
# ********** Epoch  27 **********
# Train:		Accuracy= 0.7011 	Loss= 0.8501
# Validation:	Accuracy= 0.6692 	Loss= 0.9615
#
# ********** Epoch  28 **********
# Train:		Accuracy= 0.7075 	Loss= 0.8320
# Validation:	Accuracy= 0.6728 	Loss= 0.9485
#
# ********** Epoch  29 **********
# Train:		Accuracy= 0.7138 	Loss= 0.8143
# Validation:	Accuracy= 0.6768 	Loss= 0.9364
#
# ********** Epoch  30 **********
# Train:		Accuracy= 0.7193 	Loss= 0.7976
# Validation:	Accuracy= 0.6798 	Loss= 0.9241
#
# ********** Epoch  31 **********
# Train:		Accuracy= 0.7253 	Loss= 0.7799
# Validation:	Accuracy= 0.6852 	Loss= 0.9186
#
# ********** Epoch  32 **********
# Train:		Accuracy= 0.7315 	Loss= 0.7628
# Validation:	Accuracy= 0.6868 	Loss= 0.9033
#
# ********** Epoch  33 **********
# Train:		Accuracy= 0.7378 	Loss= 0.7468
# Validation:	Accuracy= 0.6864 	Loss= 0.8999
#
# ********** Epoch  34 **********
# Train:		Accuracy= 0.7435 	Loss= 0.7310
# Validation:	Accuracy= 0.6898 	Loss= 0.9016
#
# ********** Epoch  35 **********
# Train:		Accuracy= 0.7488 	Loss= 0.7150
# Validation:	Accuracy= 0.6916 	Loss= 0.8947
#
# ********** Epoch  36 **********
# Train:		Accuracy= 0.7547 	Loss= 0.7002
# Validation:	Accuracy= 0.6952 	Loss= 0.8877
#
# ********** Epoch  37 **********
# Train:		Accuracy= 0.7599 	Loss= 0.6865
# Validation:	Accuracy= 0.6986 	Loss= 0.8823
#
# ********** Epoch  38 **********
# Train:		Accuracy= 0.7653 	Loss= 0.6735
# Validation:	Accuracy= 0.6988 	Loss= 0.8842
#
# ********** Epoch  39 **********
# Train:		Accuracy= 0.7702 	Loss= 0.6600
# Validation:	Accuracy= 0.6972 	Loss= 0.8866
#
# ********** Epoch  40 **********
# Train:		Accuracy= 0.7756 	Loss= 0.6463
# Validation:	Accuracy= 0.6986 	Loss= 0.8894
#
# ********** Epoch  41 **********
# Train:		Accuracy= 0.7804 	Loss= 0.6331
# Validation:	Accuracy= 0.7006 	Loss= 0.8937
#
# ********** Epoch  42 **********
# Train:		Accuracy= 0.7857 	Loss= 0.6187
# Validation:	Accuracy= 0.7032 	Loss= 0.8973
#
# ********** Epoch  43 **********
# Train:		Accuracy= 0.7913 	Loss= 0.6034
# Validation:	Accuracy= 0.6986 	Loss= 0.9084
#
# ********** Epoch  44 **********
# Train:		Accuracy= 0.7961 	Loss= 0.5898
# Validation:	Accuracy= 0.6998 	Loss= 0.9114
#
# ********** Epoch  45 **********
# Train:		Accuracy= 0.8020 	Loss= 0.5752
# Validation:	Accuracy= 0.7000 	Loss= 0.9156
#
# ********** Epoch  46 **********
# Train:		Accuracy= 0.8064 	Loss= 0.5627
# Validation:	Accuracy= 0.6960 	Loss= 0.9274
#
# ********** Epoch  47 **********
# Train:		Accuracy= 0.8105 	Loss= 0.5511
# Validation:	Accuracy= 0.6994 	Loss= 0.9365
#
# ********** Epoch  48 **********
# Train:		Accuracy= 0.8154 	Loss= 0.5376
# Validation:	Accuracy= 0.6988 	Loss= 0.9498
#
# ********** Epoch  49 **********
# Train:		Accuracy= 0.8193 	Loss= 0.5251
# Validation:	Accuracy= 0.6986 	Loss= 0.9661
# Test:	Accuracy= 0.6939 	Loss= 0.9914

# %% [markdown]
# ### Training Diagram

# %%
########## Plot metrics #########################
fig = plt.figure()
plt.plot(range(epochs), train_acc, label='Train')
plt.plot(range(epochs), val_acc, label='Validation')
plt.title("Training and Validation Accuracy")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend(loc=0)
plt.show()

fig = plt.figure()
plt.plot(range(epochs), train_loss, label='Train')
plt.plot(range(epochs), val_loss, label='Validation')
plt.title("Training and Validation Loss")
plt.xlabel("epoch")
plt.ylabel("Cross entropy")
plt.grid(True)
plt.legend(loc=0)
plt.show()

# %% [markdown]
# ## Part2: Visualizing the Network (5 pts.)

# %% [markdown]
# Now, we want to check the weights to see how the network realy works and what it does. Consider the wieghts of the first convolutional layer, find its weights values and print the values of 2 arbitrary filters:

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    w1 = sess.run(W_conv1)
    print(w1)
    w2 = sess.run(W_conv5)
    print(w2)
# Out:
# [[[[ 5.63396839e-03  1.12355715e-02  6.64234255e-03 ...  1.30940815e-02
#     -3.54285445e-03 -1.37719251e-02]
#    [ 1.15915434e-03  1.93954492e-03 -2.23576208e-03 ...  1.25498129e-02
#      5.80170797e-03 -5.90124575e-04]
#    [ 4.09602700e-03  1.32331438e-02 -6.33563148e-03 ...  8.21197312e-03
#      1.23517849e-02  2.88324594e-03]]
#
#   [[-9.48703662e-03 -1.78249683e-02 -1.58102706e-03 ...  1.37987109e-02
#     -1.47857575e-03 -1.49510372e-02]
#    [-4.60764952e-03  1.03328926e-02 -7.68676447e-03 ... -6.65906351e-03
#      9.96856391e-03  3.61014041e-03]
#    [-4.91148140e-03 -7.62689160e-03 -3.62300291e-03 ...  1.04420111e-02
#      6.55428041e-03  2.19812407e-03]]
#
#   [[-5.47374832e-03  4.14165575e-03 -8.62434693e-03 ... -8.18724930e-03
#      7.45933503e-04 -1.39982789e-03]
#    [ 8.37293745e-04 -1.12968190e-02 -4.00777115e-03 ...  1.24066900e-02
#      8.73741228e-03  1.32735427e-02]
#    [-5.99362236e-03 -6.89382339e-03 -1.60529962e-04 ...  8.55157897e-03
#      6.84251776e-03  9.13548004e-03]]
#
#   [[-1.63425766e-02 -8.70619435e-03  4.41235537e-03 ... -7.99682084e-03
#      1.51191801e-02 -8.13101698e-03]
#    [-6.91391947e-03  1.17716170e-03  3.29432869e-03 ...  8.39807000e-03
#     -4.79551265e-03 -6.90967077e-03]
#    [ 5.05900849e-03 -1.57150161e-02  9.94457677e-03 ... -4.52814013e-04
#      1.36635443e-02 -1.24938153e-02]]
#
#   [[-8.36053211e-03 -1.24105001e-02  6.36891695e-03 ... -1.05588399e-02
#     -3.56558408e-03 -8.97381641e-03]
#    [-1.13312784e-03 -1.38679836e-02  1.27787248e-03 ... -1.71969980e-02
#      1.46069122e-03  7.20762764e-04]
#    [-6.60480140e-03 -2.61455285e-03  8.33205588e-04 ...  1.10280151e-02
#     -8.41479807e-04  1.50936386e-02]]]
#
#
#  [[[ 9.82366595e-03  9.60733835e-03  1.24770915e-02 ...  1.76092442e-02
#     -1.98138598e-02 -5.13154129e-03]
#    [-1.12618776e-02  1.17912041e-02  1.23708125e-03 ...  1.20426258e-02
#     -3.24106961e-03  4.75357170e-04]
#    [-1.73829701e-02  1.47924209e-02  7.16284383e-03 ...  8.02931376e-03
#      3.65778082e-03  4.32792469e-04]]
#
#   [[-7.96011649e-03  3.90547956e-03  6.52369205e-03 ...  2.26718560e-03
#     -6.83559524e-03 -1.46207130e-02]
#    [-1.30465580e-03  3.25820595e-03 -1.70806125e-02 ...  3.36982729e-03
#      3.36423051e-03  2.83395429e-03]
#    ...
#    [-4.39907832e-04  2.97030644e-03 -1.43446010e-02 ... -3.59341176e-03
#      1.39216031e-03 -5.65406447e-03]
#    [ 4.95046005e-03 -2.60406663e-03  5.75442100e-03 ... -1.15134465e-02
#     -1.15140742e-02 -2.57800217e-03]
#    [ 1.95462024e-03 -2.02751881e-03 -1.25962347e-02 ...  1.62680224e-02
#     -1.06071271e-02  5.46836201e-03]]]]

# %% [markdown]
# ### Question: Try to interpret what they are doing?

# %% [markdown]
# ### Answer:

# %% [markdown]
# این وزن ها باعث می شوند که الگوی ساده ای منتقل شود که نشان میدهد که چه قسمت هایی مهم تر است

# %% [markdown]
# Now let's visualize the filters of the first conv layer. There are lots of ways to code for visualization. You are free to choose any way you want. However below is function which is provided for you to plot the weights.

# %%
import math
def plot_conv_weights(w, input_channel=0):

    w_min = np.min(w)
    w_max = np.max(w)
    abs_max = max(abs(w_min), abs(w_max))

    # Number of filters used in the conv. layer.
    num_filters = w.shape[3]

    # Number of grids to plot.
    # Rounded-up, square-root of the number of filters.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot all the filter-weights.
    for i, ax in enumerate(axes.flat):
        # Only plot the valid filter-weights.
        if i<num_filters:
            # Get the weights for the i'th filter of the input channel.
            # The format of this 4-dim tensor is determined by the
            # TensorFlow API. See Tutorial #02 for more details.
            img = w[:, :, input_channel, i]

            # Plot image.
            ax.imshow(img, vmin=-abs_max, vmax=abs_max,
                      interpolation='nearest', cmap='seismic')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

    
##########################################################################
# TODO: call the function above or use your own way here                 #
##########################################################################

plot_conv_weights(w1, 0)
##########################################################################

# %% [markdown]
# ### Question: Try to interpret what they are doing?

# %% [markdown]
# ### Answer:

# %% [markdown]
# Type your answer here...

# %% [markdown]
# از مثبت تا منفی بر اساس رنگ نشان داده شده اند که باعث می شود قسمت های مورد توجه بیشتر تکرار شوند و تاثیر داشته باشند

# %% [markdown]
# ## Part3: Transfer Learning (+10 pts. - optional)

# %% [markdown]
# In all the machine learning problems we need data to train our models. However, the volume of the data might not be sufficient for the considered model. In such cases, we may use a model which is trained on a similar dataset probably for a different objective. Then we transfer to the main problem and fine- tune or replace some parts of the network.

# %% [markdown]
# In this exercise, we are going to implement the transfer learning concept on CNN. For this purpose, we use the network that you have trained on Part 1 of this homework (above) to classify three new classes (i.e. bee, elephant, and fox) on CIFAR-100 dataset. Let's first load the data:

# %%
# from load_data import load_cifar100 #this function provided in the attached file loads the data of CIFAR100 database
from keras.datasets import cifar100

def load_cifar100_data():
    dataset_dir = 'data/cifar-100-python'
    
#     X_train, y_train, X_test, y_test = load_cifar100(dataset_dir)
    (X_train, y_train), (X_test, y_test) = cifar100.load_data()
    return X_train, y_train, X_test, y_test

# %%
X_train, y_train, X_test, y_test = load_cifar100_data()

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)

import matplotlib.pyplot as plt
plt.imshow(X_train[1])#represnting a sample data from CIFAR-100
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 25s 0us/step
# X_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# X_test shape: (10000, 32, 32, 3)
# y_test shape: (10000, 1)

# %% [markdown]
# By successfully runing the above code, you have loaded the data and also you can see a sample data from CIFAR-100. The below code will seprate the specified classes (i.e. bee(6), elephant(31), and fox(34)) for the new classification problem.

# %%
selected_images_train = np.zeros([1,32,32,3])
selected_labels_train = np.zeros([1,1])
for i in range(50000):
    label = y_train[i]
    if label==6 or label==31 or label==34:
        selected_images_train = np.append(selected_images_train,np.reshape(X_train[i,:,:,:],[1,32,32,3]),axis=0)
        selected_labels_train = np.append(selected_labels_train,np.reshape(label,[1,1]),axis=0)
selected_images_train = selected_images_train[1:]# to remove the first defined np..zeros data
selected_labels_train = selected_labels_train[1:]# to remove the first defined np..zeros data


selected_images_test = np.zeros([1,32,32,3])
selected_labels_test = np.zeros([1,1])
for i in range(10000):
    label = y_test[i]
    if label==6 or label==31 or label==34:
        selected_images_test = np.append(selected_images_test,np.reshape(X_test[i,:,:,:],[1,32,32,3]),axis=0)
        selected_labels_test = np.append(selected_labels_test,np.reshape(label,[1,1]),axis=0)
selected_images_test = selected_images_test[1:]# to remove the first defined np..zeros data
selected_labels_test = selected_labels_test[1:]# to remove the first defined np..zeros data

# %%
images_train = selected_images_train[:int(selected_images_train.shape[0]*0.8),:,:,:]
labels_train = selected_labels_train[:int(selected_images_train.shape[0]*0.8),:]

images_validation = selected_images_train[int(selected_images_train.shape[0]*0.8):,:,:,:]
labels_validation = selected_labels_train[int(selected_images_train.shape[0]*0.8):,:]

images_test = selected_images_test
labels_test = selected_labels_test


print('images_train shape:', images_train.shape)
print('labels_train shape:', labels_train.shape)

print('images_validation shape:', images_validation.shape)
print('labels_validation shape:', labels_validation.shape)

print('images_test shape:', images_test.shape)
print('labels_test shape:', labels_test.shape)
# Out:
# images_train shape: (1200, 32, 32, 3)
# labels_train shape: (1200, 1)
# images_validation shape: (300, 32, 32, 3)
# labels_validation shape: (300, 1)
# images_test shape: (300, 32, 32, 3)
# labels_test shape: (300, 1)

# %%
import numpy as np

from sklearn.preprocessing import OneHotEncoder # this function is used to prepare one-hot encoded labels
encoder = OneHotEncoder(sparse=False)

encoder.fit(selected_labels_train)#this line will fit 'encoder' to encode the labels

labels_train_onehot = encoder.transform(labels_train)# encoding train labels (one-hot coding)
labels_val_onehot   = encoder.transform(labels_validation)  # encoding train labels (one-hot coding)
labels_test_onehot  = encoder.transform(labels_test) # encoding test  labels (one-hot coding)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# To implement the transfer learning, we need to use the previous model and transfer it to the new problem. For this end, you need to freeze the convolution layers and also the first fully connected layer which means that they should not be updated in the new training process. For the last two fully connected layers, we want to fine-tune the values. However, you should replace the last layer (output layer) with a 3-neuron layer to represent the score for each class.

# %% [markdown]
# There are several methods that you can implement the discussed process with TensorFlow. You are free to do any way you want.
# The below code redefine the network and use the weights of the network trained on CIFAR-10. Then, the frozen weights can be defined as either constant or non-trainable variables. Besides, the fine-tuning weights are also defined as variables with their previous weights in the definition. Anyway, since there are other ways to implement this job, you can do it with your own method.

# %%
############################################################
#            TODO: Implement Accuracy Part                 #
############################################################

# get the weights form previous network:
# e.g., w_conv1_CIFAR10 = sess.run(W_conv1)
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())
  w_conv1_CIFAR10 = sess.run(W_conv1)
  w_conv2_CIFAR10 = sess.run(W_conv2)
  w_conv3_CIFAR10 = sess.run(W_conv3)
  w_conv4_CIFAR10 = sess.run(W_conv4)
  w_conv5_CIFAR10 = sess.run(W_conv5)
  b_conv1_CIFAR10 = sess.run(B_conv1)
  b_conv2_CIFAR10 = sess.run(B_conv2)
  b_conv3_CIFAR10 = sess.run(B_conv3)
  b_conv4_CIFAR10 = sess.run(B_conv4)
  b_conv5_CIFAR10 = sess.run(B_conv5)
  w_fc1_CIFAR10 = sess.run(W_FC1)
  b_fc1_CIFAR10 = sess.run(B_FC1)


# tf.reset_default_graph()

x_new = tf.placeholder(tf.float32, [None, 32, 32, 3]) # placeholder for input data
y_new = tf.placeholder(tf.float32, [None, 3])# placeholder for labels (one-hot encoded)

# Re-define the convolutional layers

conv1_CIFAR100 = tf.nn.conv2d(x_new, w_conv1_CIFAR10, strides=[1, 1, 1, 1], padding='SAME') + b_conv1_CIFAR10
conv1_CIFAR100_relu = tf.nn.relu(conv1_CIFAR100)
conv2_CIFAR100 = tf.nn.conv2d(conv1_CIFAR100_relu, w_conv2_CIFAR10, strides=[1, 1, 1, 1], padding='SAME') + b_conv2_CIFAR10
conv2_CIFAR100_relu = tf.nn.relu(conv2_CIFAR100)
pooling1_CIFAR100 = tf.nn.max_pool(conv2_CIFAR100_relu, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME')
conv3_CIFAR100 = tf.nn.conv2d(pooling1_CIFAR100, w_conv3_CIFAR10, strides=[1, 1, 1, 1], padding='SAME') + b_conv3_CIFAR10
conv3_CIFAR100_relu = tf.nn.relu(conv3_CIFAR100)
conv4_CIFAR100 = tf.nn.conv2d(conv3_CIFAR100_relu, w_conv4_CIFAR10, strides=[1, 1, 1, 1], padding='SAME') + b_conv4_CIFAR10
conv4_CIFAR100_relu = tf.nn.relu(conv4_CIFAR100)
pooling2_CIFAR100 = tf.nn.max_pool(conv4_CIFAR100_relu, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME')
conv5_CIFAR100 = tf.nn.conv2d(pooling2_CIFAR100, w_conv5_CIFAR10, strides=[1, 1, 1, 1], padding='SAME') + b_conv5_CIFAR10
conv5_CIFAR100_relu = tf.nn.relu(conv5_CIFAR100)   

flat_conv5_CIFAR100 = tf.reshape(conv5_CIFAR100_relu, [-1, conv5.shape[1]*conv5.shape[2]*conv5.shape[3]])

FC1_CIFAR100 = tf.matmul(flat_conv5_CIFAR100, w_fc1_CIFAR10) + b_fc1_CIFAR10
FC1_CIFAR100_relu = tf.nn.relu(FC1_CIFAR100)
# Define weights for the second FC layer (fc1 is already defined in the previous model)
W_fc2_new = tf.Variable(tf.truncated_normal(shape=[128, 128], mean = 0.0, stddev = 1),name="W_fc2_new")
B_fc2_new = tf.Variable(tf.constant(0.01, shape=[128]),name="B_fc2_new")
W_fc3_new = tf.Variable(tf.truncated_normal(shape=[128, 3], mean = 0.0, stddev = 1),name="W_fc3_new")
B_fc3_new = tf.Variable(tf.constant(0.01, shape=[3]),name="B_fc3_new")
# Define based on the first fully connected layer.
fc2_new = tf.nn.relu(tf.matmul(FC1_CIFAR100_relu, W_fc2_new) + B_fc2_new)
# Define based on the second fully connected layer (fc2_new).
logit = tf.matmul(fc2_new, W_fc3_new) + B_fc3_new

y_hat = tf.nn.softmax(logit)

#############################################################

########## Cross entropy loss ##########
new_cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logit, labels=y_new))
regularizers = tf.nn.l2_loss(W_fc3_new) + tf.nn.l2_loss(W_fc2_new)
beta=0.00001
new_cross_entropy += regularizers * beta
############################################################
#            TODO: Implement the optimizer so that only    #
#                  variales defined above are updated.     #
############################################################
lr = 3e-3
new_optimizer = tf.train.AdamOptimizer(learning_rate=lr)
new_trainer = new_optimizer.minimize(new_cross_entropy, var_list=[W_fc2_new, B_fc2_new, B_fc3_new, B_fc3_new])
############################################################

############################################################
#            TODO: Implement Accuracy                      #
############################################################
correct_preds = tf.argmax(y_new, axis=1)
new_accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(y_hat, axis=1), correct_preds),tf.float64))
############################################################

# %% [markdown]
# Now, go for the rest of the job and start training:

# %%
########## Training ##########
batch_size = 40 # You are free to change it
x_train_batches, y_train_batches = make_batches(images_train, labels_train_onehot, batch_size)
epochs = 200# You are free to change it
N_Batches = len(x_train_batches)

train_acc  = np.zeros(epochs)
train_loss = np.zeros(epochs)
val_acc  = np.zeros(epochs)
val_loss = np.zeros(epochs)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(epochs):
        print()
        print("*" * 10, "Epoch %3i"%epoch, "*" * 10)

        batch_acc = np.zeros(N_Batches)
        batch_loss = np.zeros(N_Batches)
        for n in range(N_Batches):
            _, batch_acc[n], batch_loss[n] = sess.run([new_trainer, new_accuracy, new_cross_entropy],
                                                      {x_new: x_train_batches[n], y_new: y_train_batches[n]})
            #print("Batch %3d/%d: Acc:%0.4f , Loss:%0.4f"%(n, N_Batches, batch_acc[n], batch_loss[n]))

        train_acc[epoch] = np.mean(batch_acc)
        train_loss[epoch] = np.mean(batch_loss)
        print("Train:\t\tAccuracy= %0.4f \tLoss= %0.4f"%(train_acc[epoch], train_loss[epoch]))

        ########## Validation ##########
        val_acc[epoch], val_loss[epoch] = sess.run([new_accuracy, new_cross_entropy],
                                                   {x_new: images_validation, y_new: labels_val_onehot})
        print("Validation:\tAccuracy= %0.4f \tLoss= %0.4f"%(val_acc[epoch], val_loss[epoch]))
        
############################################################
#            TODO: Implement Test Phase                    #
############################################################
    test_acc, test_loss = sess.run([new_accuracy, new_cross_entropy],{x_new: images_test, y_new: labels_test_onehot})
    print("Test:\tAccuracy= %0.4f \tLoss= %0.4f"%(test_acc, test_loss))
############################################################
# Out:
# ********** Epoch   0 **********
# Train:		Accuracy= 0.3892 	Loss= 1.5071
# Validation:	Accuracy= 0.4400 	Loss= 1.1021
#
# ********** Epoch   1 **********
# Train:		Accuracy= 0.4633 	Loss= 1.0837
# Validation:	Accuracy= 0.4533 	Loss= 1.0397
#
# ********** Epoch   2 **********
# Train:		Accuracy= 0.5267 	Loss= 1.0278
# Validation:	Accuracy= 0.5433 	Loss= 0.9799
#
# ********** Epoch   3 **********
# Train:		Accuracy= 0.5608 	Loss= 0.9889
# Validation:	Accuracy= 0.5667 	Loss= 0.9421
#
# ********** Epoch   4 **********
# Train:		Accuracy= 0.5767 	Loss= 0.9582
# Validation:	Accuracy= 0.5800 	Loss= 0.9137
#
# ********** Epoch   5 **********
# Train:		Accuracy= 0.5917 	Loss= 0.9321
# Validation:	Accuracy= 0.5967 	Loss= 0.8910
#
# ********** Epoch   6 **********
# Train:		Accuracy= 0.6033 	Loss= 0.9105
# Validation:	Accuracy= 0.6067 	Loss= 0.8730
#
# ********** Epoch   7 **********
# Train:		Accuracy= 0.6133 	Loss= 0.8928
# Validation:	Accuracy= 0.6267 	Loss= 0.8569
#
# ********** Epoch   8 **********
# Train:		Accuracy= 0.6300 	Loss= 0.8777
# Validation:	Accuracy= 0.6433 	Loss= 0.8444
#
# ********** Epoch   9 **********
# Train:		Accuracy= 0.6358 	Loss= 0.8645
# Validation:	Accuracy= 0.6500 	Loss= 0.8323
#
# ********** Epoch  10 **********
# Train:		Accuracy= 0.6417 	Loss= 0.8528
# Validation:	Accuracy= 0.6500 	Loss= 0.8231
#
# ********** Epoch  11 **********
# Train:		Accuracy= 0.6433 	Loss= 0.8427
# Validation:	Accuracy= 0.6533 	Loss= 0.8147
#
# ********** Epoch  12 **********
# Train:		Accuracy= 0.6467 	Loss= 0.8335
# Validation:	Accuracy= 0.6633 	Loss= 0.8071
#
# ********** Epoch  13 **********
# Train:		Accuracy= 0.6508 	Loss= 0.8254
# Validation:	Accuracy= 0.6700 	Loss= 0.8005
#
# ********** Epoch  14 **********
# Train:		Accuracy= 0.6558 	Loss= 0.8181
# Validation:	Accuracy= 0.6667 	Loss= 0.7950
#
# ********** Epoch  15 **********
# Train:		Accuracy= 0.6567 	Loss= 0.8114
# Validation:	Accuracy= 0.6667 	Loss= 0.7893
#
# ********** Epoch  16 **********
# Train:		Accuracy= 0.6600 	Loss= 0.8054
# Validation:	Accuracy= 0.6667 	Loss= 0.7856
#
# ********** Epoch  17 **********
# Train:		Accuracy= 0.6617 	Loss= 0.8000
# Validation:	Accuracy= 0.6733 	Loss= 0.7814
#
# ********** Epoch  18 **********
# Train:		Accuracy= 0.6667 	Loss= 0.7948
# Validation:	Accuracy= 0.6800 	Loss= 0.7773
#
# ********** Epoch  19 **********
# Train:		Accuracy= 0.6667 	Loss= 0.7901
# Validation:	Accuracy= 0.6867 	Loss= 0.7741
#
# ********** Epoch  20 **********
# Train:		Accuracy= 0.6692 	Loss= 0.7859
# Validation:	Accuracy= 0.6800 	Loss= 0.7707
#
# ********** Epoch  21 **********
# Train:		Accuracy= 0.6667 	Loss= 0.7826
# Validation:	Accuracy= 0.6800 	Loss= 0.7679
#
# ********** Epoch  22 **********
# Train:		Accuracy= 0.6675 	Loss= 0.7771
# Validation:	Accuracy= 0.6567 	Loss= 0.7716
#
# ********** Epoch  23 **********
# Train:		Accuracy= 0.6675 	Loss= 0.7789
# Validation:	Accuracy= 0.6633 	Loss= 0.7666
#
# ********** Epoch  24 **********
# Train:		Accuracy= 0.6642 	Loss= 0.7789
# Validation:	Accuracy= 0.6733 	Loss= 0.7621
#
# ********** Epoch  25 **********
# Train:		Accuracy= 0.6617 	Loss= 0.7745
# Validation:	Accuracy= 0.6933 	Loss= 0.7569
#
# ********** Epoch  26 **********
# Train:		Accuracy= 0.6708 	Loss= 0.7652
# Validation:	Accuracy= 0.6800 	Loss= 0.7556
#
# ********** Epoch  27 **********
# Train:		Accuracy= 0.6758 	Loss= 0.7622
# Validation:	Accuracy= 0.6867 	Loss= 0.7534
#
# ********** Epoch  28 **********
# Train:		Accuracy= 0.6783 	Loss= 0.7588
# Validation:	Accuracy= 0.6833 	Loss= 0.7511
#
# ********** Epoch  29 **********
# Train:		Accuracy= 0.6792 	Loss= 0.7553
# Validation:	Accuracy= 0.6900 	Loss= 0.7499
#
# ********** Epoch  30 **********
# Train:		Accuracy= 0.6808 	Loss= 0.7540
# Validation:	Accuracy= 0.6867 	Loss= 0.7474
#
# ********** Epoch  31 **********
# Train:		Accuracy= 0.6792 	Loss= 0.7509
# Validation:	Accuracy= 0.6867 	Loss= 0.7460
#
# ********** Epoch  32 **********
# Train:		Accuracy= 0.6842 	Loss= 0.7481
# Validation:	Accuracy= 0.7033 	Loss= 0.7423
#
# ********** Epoch  33 **********
# Train:		Accuracy= 0.6808 	Loss= 0.7453
# Validation:	Accuracy= 0.6800 	Loss= 0.7469
#
# ********** Epoch  34 **********
# Train:		Accuracy= 0.6858 	Loss= 0.7446
# Validation:	Accuracy= 0.6867 	Loss= 0.7435
#
# ********** Epoch  35 **********
# Train:		Accuracy= 0.6858 	Loss= 0.7418
# Validation:	Accuracy= 0.6867 	Loss= 0.7410
#
# ********** Epoch  36 **********
# Train:		Accuracy= 0.6867 	Loss= 0.7395
# Validation:	Accuracy= 0.6867 	Loss= 0.7402
#
# ********** Epoch  37 **********
# Train:		Accuracy= 0.6867 	Loss= 0.7377
# Validation:	Accuracy= 0.6833 	Loss= 0.7379
#
# ********** Epoch  38 **********
# Train:		Accuracy= 0.6900 	Loss= 0.7352
# Validation:	Accuracy= 0.6800 	Loss= 0.7436
#
# ********** Epoch  39 **********
# Train:		Accuracy= 0.6825 	Loss= 0.7379
# Validation:	Accuracy= 0.6900 	Loss= 0.7386
#
# ********** Epoch  40 **********
# Train:		Accuracy= 0.6842 	Loss= 0.7352
# Validation:	Accuracy= 0.6933 	Loss= 0.7375
#
# ********** Epoch  41 **********
# Train:		Accuracy= 0.6867 	Loss= 0.7317
# Validation:	Accuracy= 0.6900 	Loss= 0.7334
#
# ********** Epoch  42 **********
# Train:		Accuracy= 0.6842 	Loss= 0.7303
# Validation:	Accuracy= 0.6867 	Loss= 0.7389
#
# ********** Epoch  43 **********
# Train:		Accuracy= 0.6875 	Loss= 0.7304
# Validation:	Accuracy= 0.6900 	Loss= 0.7379
#
# ********** Epoch  44 **********
# Train:		Accuracy= 0.6892 	Loss= 0.7281
# Validation:	Accuracy= 0.6933 	Loss= 0.7358
#
# ********** Epoch  45 **********
# Train:		Accuracy= 0.6892 	Loss= 0.7259
# Validation:	Accuracy= 0.6933 	Loss= 0.7346
#
# ********** Epoch  46 **********
# Train:		Accuracy= 0.6917 	Loss= 0.7241
# Validation:	Accuracy= 0.6933 	Loss= 0.7338
#
# ********** Epoch  47 **********
# Train:		Accuracy= 0.6925 	Loss= 0.7229
# Validation:	Accuracy= 0.6933 	Loss= 0.7336
#
# ********** Epoch  48 **********
# Train:		Accuracy= 0.6925 	Loss= 0.7213
# Validation:	Accuracy= 0.6933 	Loss= 0.7323
#
# ********** Epoch  49 **********
# Train:		Accuracy= 0.6933 	Loss= 0.7197
# Validation:	Accuracy= 0.6933 	Loss= 0.7319
#
# ********** Epoch  50 **********
# Train:		Accuracy= 0.6950 	Loss= 0.7185
# Validation:	Accuracy= 0.6967 	Loss= 0.7309
#
# ********** Epoch  51 **********
# Train:		Accuracy= 0.6975 	Loss= 0.7170
# Validation:	Accuracy= 0.7000 	Loss= 0.7309
#
# ********** Epoch  52 **********
# Train:		Accuracy= 0.6983 	Loss= 0.7159
# Validation:	Accuracy= 0.7000 	Loss= 0.7300
#
# ********** Epoch  53 **********
# Train:		Accuracy= 0.6967 	Loss= 0.7146
# Validation:	Accuracy= 0.7000 	Loss= 0.7295
#
# ********** Epoch  54 **********
# Train:		Accuracy= 0.6975 	Loss= 0.7134
# Validation:	Accuracy= 0.7000 	Loss= 0.7287
#
# ********** Epoch  55 **********
# Train:		Accuracy= 0.6967 	Loss= 0.7120
# Validation:	Accuracy= 0.7000 	Loss= 0.7284
#
# ********** Epoch  56 **********
# Train:		Accuracy= 0.6983 	Loss= 0.7110
# Validation:	Accuracy= 0.6967 	Loss= 0.7287
#
# ********** Epoch  57 **********
# Train:		Accuracy= 0.6983 	Loss= 0.7096
# Validation:	Accuracy= 0.7000 	Loss= 0.7262
#
# ********** Epoch  58 **********
# Train:		Accuracy= 0.7025 	Loss= 0.7083
# Validation:	Accuracy= 0.6967 	Loss= 0.7280
#
# ********** Epoch  59 **********
# Train:		Accuracy= 0.7017 	Loss= 0.7076
# Validation:	Accuracy= 0.7000 	Loss= 0.7266
#
# ********** Epoch  60 **********
# Train:		Accuracy= 0.7042 	Loss= 0.7063
# Validation:	Accuracy= 0.7000 	Loss= 0.7270
#
# ********** Epoch  61 **********
# Train:		Accuracy= 0.7033 	Loss= 0.7055
# Validation:	Accuracy= 0.7000 	Loss= 0.7259
#
# ********** Epoch  62 **********
# Train:		Accuracy= 0.7033 	Loss= 0.7041
# Validation:	Accuracy= 0.7000 	Loss= 0.7261
#
# ********** Epoch  63 **********
# Train:		Accuracy= 0.7042 	Loss= 0.7034
# Validation:	Accuracy= 0.7000 	Loss= 0.7256
#
# ********** Epoch  64 **********
# Train:		Accuracy= 0.7042 	Loss= 0.7025
# Validation:	Accuracy= 0.7000 	Loss= 0.7257
#
# ********** Epoch  65 **********
# Train:		Accuracy= 0.7050 	Loss= 0.7016
# Validation:	Accuracy= 0.7000 	Loss= 0.7247
#
# ********** Epoch  66 **********
# Train:		Accuracy= 0.7042 	Loss= 0.7006
# Validation:	Accuracy= 0.7000 	Loss= 0.7257
#
# ********** Epoch  67 **********
# Train:		Accuracy= 0.7050 	Loss= 0.6999
# Validation:	Accuracy= 0.6933 	Loss= 0.7245
#
# ********** Epoch  68 **********
# Train:		Accuracy= 0.7042 	Loss= 0.6989
# Validation:	Accuracy= 0.6967 	Loss= 0.7241
#
# ********** Epoch  69 **********
# Train:		Accuracy= 0.7058 	Loss= 0.6980
# Validation:	Accuracy= 0.6967 	Loss= 0.7238
#
# ********** Epoch  70 **********
# Train:		Accuracy= 0.7033 	Loss= 0.6975
# Validation:	Accuracy= 0.6967 	Loss= 0.7249
#
# ********** Epoch  71 **********
# Train:		Accuracy= 0.7067 	Loss= 0.6966
# Validation:	Accuracy= 0.7000 	Loss= 0.7231
#
# ********** Epoch  72 **********
# Train:		Accuracy= 0.7042 	Loss= 0.6958
# Validation:	Accuracy= 0.6967 	Loss= 0.7240
#
# ********** Epoch  73 **********
# Train:		Accuracy= 0.7100 	Loss= 0.6947
# Validation:	Accuracy= 0.6967 	Loss= 0.7237
#
# ********** Epoch  74 **********
# Train:		Accuracy= 0.7075 	Loss= 0.6942
# Validation:	Accuracy= 0.6967 	Loss= 0.7232
#
# ********** Epoch  75 **********
# Train:		Accuracy= 0.7075 	Loss= 0.6934
# Validation:	Accuracy= 0.7000 	Loss= 0.7226
#
# ********** Epoch  76 **********
# Train:		Accuracy= 0.7100 	Loss= 0.6924
# Validation:	Accuracy= 0.6967 	Loss= 0.7229
#
# ********** Epoch  77 **********
# Train:		Accuracy= 0.7117 	Loss= 0.6920
# Validation:	Accuracy= 0.6967 	Loss= 0.7221
#
# ********** Epoch  78 **********
# Train:		Accuracy= 0.7100 	Loss= 0.6908
# Validation:	Accuracy= 0.6933 	Loss= 0.7224
#
# ********** Epoch  79 **********
# Train:		Accuracy= 0.7125 	Loss= 0.6904
# Validation:	Accuracy= 0.6967 	Loss= 0.7224
#
# ********** Epoch  80 **********
# Train:		Accuracy= 0.7108 	Loss= 0.6896
# Validation:	Accuracy= 0.6967 	Loss= 0.7220
#
# ********** Epoch  81 **********
# Train:		Accuracy= 0.7133 	Loss= 0.6892
# Validation:	Accuracy= 0.6933 	Loss= 0.7222
#
# ********** Epoch  82 **********
# Train:		Accuracy= 0.7108 	Loss= 0.6882
# Validation:	Accuracy= 0.6967 	Loss= 0.7212
#
# ********** Epoch  83 **********
# Train:		Accuracy= 0.7142 	Loss= 0.6877
# Validation:	Accuracy= 0.6933 	Loss= 0.7217
#
# ********** Epoch  84 **********
# Train:		Accuracy= 0.7142 	Loss= 0.6868
# Validation:	Accuracy= 0.6933 	Loss= 0.7217
#
# ********** Epoch  85 **********
# Train:		Accuracy= 0.7142 	Loss= 0.6866
# Validation:	Accuracy= 0.6933 	Loss= 0.7214
#
# ********** Epoch  86 **********
# Train:		Accuracy= 0.7142 	Loss= 0.6855
# Validation:	Accuracy= 0.6933 	Loss= 0.7210
#
# ********** Epoch  87 **********
# Train:		Accuracy= 0.7158 	Loss= 0.6849
# Validation:	Accuracy= 0.6933 	Loss= 0.7212
#
# ********** Epoch  88 **********
# Train:		Accuracy= 0.7175 	Loss= 0.6843
# Validation:	Accuracy= 0.6933 	Loss= 0.7211
#
# ********** Epoch  89 **********
# Train:		Accuracy= 0.7167 	Loss= 0.6839
# Validation:	Accuracy= 0.6933 	Loss= 0.7213
#
# ********** Epoch  90 **********
# Train:		Accuracy= 0.7192 	Loss= 0.6830
# Validation:	Accuracy= 0.6933 	Loss= 0.7216
#
# ********** Epoch  91 **********
# Train:		Accuracy= 0.7175 	Loss= 0.6829
# Validation:	Accuracy= 0.6933 	Loss= 0.7209
#
# ********** Epoch  92 **********
# Train:		Accuracy= 0.7183 	Loss= 0.6819
# Validation:	Accuracy= 0.6933 	Loss= 0.7208
#
# ********** Epoch  93 **********
# Train:		Accuracy= 0.7175 	Loss= 0.6815
# Validation:	Accuracy= 0.6933 	Loss= 0.7209
#
# ********** Epoch  94 **********
# Train:		Accuracy= 0.7192 	Loss= 0.6807
# Validation:	Accuracy= 0.6933 	Loss= 0.7208
#
# ********** Epoch  95 **********
# Train:		Accuracy= 0.7192 	Loss= 0.6804
# Validation:	Accuracy= 0.6967 	Loss= 0.7210
#
# ********** Epoch  96 **********
# Train:		Accuracy= 0.7208 	Loss= 0.6795
# Validation:	Accuracy= 0.6933 	Loss= 0.7199
#
# ********** Epoch  97 **********
# Train:		Accuracy= 0.7200 	Loss= 0.6793
# Validation:	Accuracy= 0.6933 	Loss= 0.7204
#
# ********** Epoch  98 **********
# Train:		Accuracy= 0.7217 	Loss= 0.6782
# Validation:	Accuracy= 0.6967 	Loss= 0.7201
#
# ********** Epoch  99 **********
# Train:		Accuracy= 0.7208 	Loss= 0.6782
# Validation:	Accuracy= 0.6967 	Loss= 0.7205
#
# ********** Epoch 100 **********
# Train:		Accuracy= 0.7217 	Loss= 0.6771
# Validation:	Accuracy= 0.6967 	Loss= 0.7193
#
# ********** Epoch 101 **********
# Train:		Accuracy= 0.7233 	Loss= 0.6766
# Validation:	Accuracy= 0.6967 	Loss= 0.7208
#
# ********** Epoch 102 **********
# Train:		Accuracy= 0.7208 	Loss= 0.6767
# Validation:	Accuracy= 0.7000 	Loss= 0.7209
#
# ********** Epoch 103 **********
# Train:		Accuracy= 0.7242 	Loss= 0.6762
# Validation:	Accuracy= 0.6967 	Loss= 0.7201
#
# ********** Epoch 104 **********
# Train:		Accuracy= 0.7258 	Loss= 0.6752
# Validation:	Accuracy= 0.6967 	Loss= 0.7194
#
# ********** Epoch 105 **********
# Train:		Accuracy= 0.7258 	Loss= 0.6746
# Validation:	Accuracy= 0.6967 	Loss= 0.7200
#
# ********** Epoch 106 **********
# Train:		Accuracy= 0.7250 	Loss= 0.6742
# Validation:	Accuracy= 0.6967 	Loss= 0.7194
#
# ********** Epoch 107 **********
# Train:		Accuracy= 0.7267 	Loss= 0.6737
# Validation:	Accuracy= 0.6967 	Loss= 0.7190
#
# ********** Epoch 108 **********
# Train:		Accuracy= 0.7250 	Loss= 0.6725
# Validation:	Accuracy= 0.6967 	Loss= 0.7193
#
# ********** Epoch 109 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6727
# Validation:	Accuracy= 0.7000 	Loss= 0.7194
#
# ********** Epoch 110 **********
# Train:		Accuracy= 0.7250 	Loss= 0.6719
# Validation:	Accuracy= 0.6967 	Loss= 0.7191
#
# ********** Epoch 111 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6715
# Validation:	Accuracy= 0.6967 	Loss= 0.7188
#
# ********** Epoch 112 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6707
# Validation:	Accuracy= 0.7000 	Loss= 0.7197
#
# ********** Epoch 113 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6709
# Validation:	Accuracy= 0.7000 	Loss= 0.7187
#
# ********** Epoch 114 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6696
# Validation:	Accuracy= 0.6967 	Loss= 0.7189
#
# ********** Epoch 115 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6697
# Validation:	Accuracy= 0.7000 	Loss= 0.7189
#
# ********** Epoch 116 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6690
# Validation:	Accuracy= 0.7000 	Loss= 0.7189
#
# ********** Epoch 117 **********
# Train:		Accuracy= 0.7292 	Loss= 0.6685
# Validation:	Accuracy= 0.6967 	Loss= 0.7182
#
# ********** Epoch 118 **********
# Train:		Accuracy= 0.7292 	Loss= 0.6681
# Validation:	Accuracy= 0.7000 	Loss= 0.7189
#
# ********** Epoch 119 **********
# Train:		Accuracy= 0.7300 	Loss= 0.6677
# Validation:	Accuracy= 0.7000 	Loss= 0.7180
#
# ********** Epoch 120 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6670
# Validation:	Accuracy= 0.7000 	Loss= 0.7187
#
# ********** Epoch 121 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6668
# Validation:	Accuracy= 0.7033 	Loss= 0.7179
#
# ********** Epoch 122 **********
# Train:		Accuracy= 0.7292 	Loss= 0.6660
# Validation:	Accuracy= 0.7033 	Loss= 0.7190
#
# ********** Epoch 123 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6660
# Validation:	Accuracy= 0.7033 	Loss= 0.7184
#
# ********** Epoch 124 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6655
# Validation:	Accuracy= 0.7067 	Loss= 0.7188
#
# ********** Epoch 125 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6648
# Validation:	Accuracy= 0.7067 	Loss= 0.7185
#
# ********** Epoch 126 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6644
# Validation:	Accuracy= 0.7033 	Loss= 0.7184
#
# ********** Epoch 127 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6641
# Validation:	Accuracy= 0.7067 	Loss= 0.7188
#
# ********** Epoch 128 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6635
# Validation:	Accuracy= 0.7000 	Loss= 0.7183
#
# ********** Epoch 129 **********
# Train:		Accuracy= 0.7258 	Loss= 0.6633
# Validation:	Accuracy= 0.7067 	Loss= 0.7187
#
# ********** Epoch 130 **********
# Train:		Accuracy= 0.7275 	Loss= 0.6626
# Validation:	Accuracy= 0.7033 	Loss= 0.7186
#
# ********** Epoch 131 **********
# Train:		Accuracy= 0.7258 	Loss= 0.6624
# Validation:	Accuracy= 0.7067 	Loss= 0.7185
#
# ********** Epoch 132 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6619
# Validation:	Accuracy= 0.7033 	Loss= 0.7187
#
# ********** Epoch 133 **********
# Train:		Accuracy= 0.7267 	Loss= 0.6615
# Validation:	Accuracy= 0.7067 	Loss= 0.7186
#
# ********** Epoch 134 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6611
# Validation:	Accuracy= 0.7033 	Loss= 0.7188
#
# ********** Epoch 135 **********
# Train:		Accuracy= 0.7300 	Loss= 0.6608
# Validation:	Accuracy= 0.7067 	Loss= 0.7183
#
# ********** Epoch 136 **********
# Train:		Accuracy= 0.7283 	Loss= 0.6603
# Validation:	Accuracy= 0.7033 	Loss= 0.7189
#
# ********** Epoch 137 **********
# Train:		Accuracy= 0.7292 	Loss= 0.6601
# Validation:	Accuracy= 0.7100 	Loss= 0.7183
#
# ********** Epoch 138 **********
# Train:		Accuracy= 0.7300 	Loss= 0.6597
# Validation:	Accuracy= 0.7033 	Loss= 0.7187
#
# ********** Epoch 139 **********
# Train:		Accuracy= 0.7317 	Loss= 0.6594
# Validation:	Accuracy= 0.7100 	Loss= 0.7183
#
# ********** Epoch 140 **********
# Train:		Accuracy= 0.7317 	Loss= 0.6589
# Validation:	Accuracy= 0.7100 	Loss= 0.7191
#
# ********** Epoch 141 **********
# Train:		Accuracy= 0.7308 	Loss= 0.6586
# Validation:	Accuracy= 0.7100 	Loss= 0.7178
#
# ********** Epoch 142 **********
# Train:		Accuracy= 0.7325 	Loss= 0.6579
# Validation:	Accuracy= 0.7100 	Loss= 0.7189
#
# ********** Epoch 143 **********
# Train:		Accuracy= 0.7325 	Loss= 0.6579
# Validation:	Accuracy= 0.7100 	Loss= 0.7181
#
# ********** Epoch 144 **********
# Train:		Accuracy= 0.7325 	Loss= 0.6572
# Validation:	Accuracy= 0.7100 	Loss= 0.7190
#
# ********** Epoch 145 **********
# Train:		Accuracy= 0.7308 	Loss= 0.6571
# Validation:	Accuracy= 0.7100 	Loss= 0.7182
#
# ********** Epoch 146 **********
# Train:		Accuracy= 0.7325 	Loss= 0.6565
# Validation:	Accuracy= 0.7100 	Loss= 0.7185
#
# ********** Epoch 147 **********
# Train:		Accuracy= 0.7333 	Loss= 0.6563
# Validation:	Accuracy= 0.7100 	Loss= 0.7180
#
# ********** Epoch 148 **********
# Train:		Accuracy= 0.7333 	Loss= 0.6558
# Validation:	Accuracy= 0.7100 	Loss= 0.7190
#
# ********** Epoch 149 **********
# Train:		Accuracy= 0.7317 	Loss= 0.6555
# Validation:	Accuracy= 0.7100 	Loss= 0.7176
#
# ********** Epoch 150 **********
# Train:		Accuracy= 0.7367 	Loss= 0.6550
# Validation:	Accuracy= 0.7100 	Loss= 0.7192
#
# ********** Epoch 151 **********
# Train:		Accuracy= 0.7325 	Loss= 0.6548
# Validation:	Accuracy= 0.7100 	Loss= 0.7177
#
# ********** Epoch 152 **********
# Train:		Accuracy= 0.7350 	Loss= 0.6543
# Validation:	Accuracy= 0.7100 	Loss= 0.7188
#
# ********** Epoch 153 **********
# Train:		Accuracy= 0.7333 	Loss= 0.6542
# Validation:	Accuracy= 0.7100 	Loss= 0.7183
#
# ********** Epoch 154 **********
# Train:		Accuracy= 0.7358 	Loss= 0.6537
# Validation:	Accuracy= 0.7100 	Loss= 0.7186
#
# ********** Epoch 155 **********
# Train:		Accuracy= 0.7358 	Loss= 0.6533
# Validation:	Accuracy= 0.7100 	Loss= 0.7182
#
# ********** Epoch 156 **********
# Train:		Accuracy= 0.7350 	Loss= 0.6531
# Validation:	Accuracy= 0.7100 	Loss= 0.7190
#
# ********** Epoch 157 **********
# Train:		Accuracy= 0.7367 	Loss= 0.6528
# Validation:	Accuracy= 0.7100 	Loss= 0.7177
#
# ********** Epoch 158 **********
# Train:		Accuracy= 0.7383 	Loss= 0.6524
# Validation:	Accuracy= 0.7133 	Loss= 0.7189
#
# ********** Epoch 159 **********
# Train:		Accuracy= 0.7350 	Loss= 0.6521
# Validation:	Accuracy= 0.7100 	Loss= 0.7178
#
# ********** Epoch 160 **********
# Train:		Accuracy= 0.7367 	Loss= 0.6516
# Validation:	Accuracy= 0.7133 	Loss= 0.7186
#
# ********** Epoch 161 **********
# Train:		Accuracy= 0.7367 	Loss= 0.6514
# Validation:	Accuracy= 0.7100 	Loss= 0.7175
#
# ********** Epoch 162 **********
# Train:		Accuracy= 0.7392 	Loss= 0.6510
# Validation:	Accuracy= 0.7133 	Loss= 0.7188
#
# ********** Epoch 163 **********
# Train:		Accuracy= 0.7367 	Loss= 0.6508
# Validation:	Accuracy= 0.7100 	Loss= 0.7179
#
# ********** Epoch 164 **********
# Train:		Accuracy= 0.7383 	Loss= 0.6503
# Validation:	Accuracy= 0.7100 	Loss= 0.7189
#
# ********** Epoch 165 **********
# Train:		Accuracy= 0.7367 	Loss= 0.6501
# Validation:	Accuracy= 0.7100 	Loss= 0.7180
#
# ********** Epoch 166 **********
# Train:		Accuracy= 0.7375 	Loss= 0.6496
# Validation:	Accuracy= 0.7100 	Loss= 0.7189
#
# ********** Epoch 167 **********
# Train:		Accuracy= 0.7375 	Loss= 0.6495
# Validation:	Accuracy= 0.7100 	Loss= 0.7176
#
# ********** Epoch 168 **********
# Train:		Accuracy= 0.7375 	Loss= 0.6491
# Validation:	Accuracy= 0.7100 	Loss= 0.7184
#
# ********** Epoch 169 **********
# Train:		Accuracy= 0.7383 	Loss= 0.6486
# Validation:	Accuracy= 0.7100 	Loss= 0.7184
#
# ********** Epoch 170 **********
# Train:		Accuracy= 0.7392 	Loss= 0.6483
# Validation:	Accuracy= 0.7100 	Loss= 0.7184
#
# ********** Epoch 171 **********
# Train:		Accuracy= 0.7383 	Loss= 0.6480
# Validation:	Accuracy= 0.7100 	Loss= 0.7183
#
# ********** Epoch 172 **********
# Train:		Accuracy= 0.7375 	Loss= 0.6477
# Validation:	Accuracy= 0.7100 	Loss= 0.7187
#
# ********** Epoch 173 **********
# Train:		Accuracy= 0.7392 	Loss= 0.6476
# Validation:	Accuracy= 0.7100 	Loss= 0.7190
#
# ********** Epoch 174 **********
# Train:		Accuracy= 0.7400 	Loss= 0.6474
# Validation:	Accuracy= 0.7100 	Loss= 0.7192
#
# ********** Epoch 175 **********
# Train:		Accuracy= 0.7408 	Loss= 0.6469
# Validation:	Accuracy= 0.7100 	Loss= 0.7180
#
# ********** Epoch 176 **********
# Train:		Accuracy= 0.7408 	Loss= 0.6464
# Validation:	Accuracy= 0.7100 	Loss= 0.7192
#
# ********** Epoch 177 **********
# Train:		Accuracy= 0.7408 	Loss= 0.6465
# Validation:	Accuracy= 0.7100 	Loss= 0.7191
#
# ********** Epoch 178 **********
# Train:		Accuracy= 0.7408 	Loss= 0.6461
# Validation:	Accuracy= 0.7067 	Loss= 0.7186
#
# ********** Epoch 179 **********
# Train:		Accuracy= 0.7425 	Loss= 0.6457
# Validation:	Accuracy= 0.7100 	Loss= 0.7187
#
# ********** Epoch 180 **********
# Train:		Accuracy= 0.7425 	Loss= 0.6454
# Validation:	Accuracy= 0.7100 	Loss= 0.7188
#
# ********** Epoch 181 **********
# Train:		Accuracy= 0.7425 	Loss= 0.6450
# Validation:	Accuracy= 0.7067 	Loss= 0.7186
#
# ********** Epoch 182 **********
# Train:		Accuracy= 0.7417 	Loss= 0.6447
# Validation:	Accuracy= 0.7067 	Loss= 0.7193
#
# ********** Epoch 183 **********
# Train:		Accuracy= 0.7417 	Loss= 0.6445
# Validation:	Accuracy= 0.7067 	Loss= 0.7195
#
# ********** Epoch 184 **********
# Train:		Accuracy= 0.7425 	Loss= 0.6442
# Validation:	Accuracy= 0.7067 	Loss= 0.7192
#
# ********** Epoch 185 **********
# Train:		Accuracy= 0.7425 	Loss= 0.6439
# Validation:	Accuracy= 0.7067 	Loss= 0.7192
#
# ********** Epoch 186 **********
# Train:		Accuracy= 0.7433 	Loss= 0.6436
# Validation:	Accuracy= 0.7033 	Loss= 0.7198
#
# ********** Epoch 187 **********
# Train:		Accuracy= 0.7417 	Loss= 0.6434
# Validation:	Accuracy= 0.7033 	Loss= 0.7193
#
# ********** Epoch 188 **********
# Train:		Accuracy= 0.7442 	Loss= 0.6430
# Validation:	Accuracy= 0.7033 	Loss= 0.7196
#
# ********** Epoch 189 **********
# Train:		Accuracy= 0.7433 	Loss= 0.6425
# Validation:	Accuracy= 0.7033 	Loss= 0.7187
#
# ********** Epoch 190 **********
# Train:		Accuracy= 0.7450 	Loss= 0.6423
# Validation:	Accuracy= 0.7033 	Loss= 0.7199
#
# ********** Epoch 191 **********
# Train:		Accuracy= 0.7450 	Loss= 0.6421
# Validation:	Accuracy= 0.7033 	Loss= 0.7189
#
# ********** Epoch 192 **********
# Train:		Accuracy= 0.7442 	Loss= 0.6419
# Validation:	Accuracy= 0.7033 	Loss= 0.7198
#
# ********** Epoch 193 **********
# Train:		Accuracy= 0.7442 	Loss= 0.6417
# Validation:	Accuracy= 0.7033 	Loss= 0.7194
#
# ********** Epoch 194 **********
# Train:		Accuracy= 0.7442 	Loss= 0.6415
# Validation:	Accuracy= 0.7033 	Loss= 0.7192
#
# ********** Epoch 195 **********
# Train:		Accuracy= 0.7450 	Loss= 0.6412
# Validation:	Accuracy= 0.7033 	Loss= 0.7203
#
# ********** Epoch 196 **********
# Train:		Accuracy= 0.7475 	Loss= 0.6409
# Validation:	Accuracy= 0.7033 	Loss= 0.7193
#
# ********** Epoch 197 **********
# Train:		Accuracy= 0.7458 	Loss= 0.6405
# Validation:	Accuracy= 0.7033 	Loss= 0.7192
#
# ********** Epoch 198 **********
# Train:		Accuracy= 0.7458 	Loss= 0.6402
# Validation:	Accuracy= 0.7033 	Loss= 0.7198
#
# ********** Epoch 199 **********
# Train:		Accuracy= 0.7467 	Loss= 0.6400
# Validation:	Accuracy= 0.7033 	Loss= 0.7194
# Test:	Accuracy= 0.7067 	Loss= 0.7476

# %% [markdown]
# You can use tensorboard or the code provided in the next box to plot for loss and accuracy of training and validation data. You are expected to achieve at least 80% accuracy on the test data after training. Good Luck! ;)

# %% [markdown]
# ### Training Diagram

# %%
########## Plot metrics #########################
fig = plt.figure()
plt.plot(range(epochs), train_acc, label='Train')
plt.plot(range(epochs), val_acc, label='Validation')
plt.title("Training and Validation Accuracy")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend(loc=0)
plt.show()

fig = plt.figure()
plt.plot(range(epochs), train_loss, label='Train')
plt.plot(range(epochs), val_loss, label='Validation')
plt.title("Training and Validation Loss")
plt.xlabel("epoch")
plt.ylabel("Cross entropy")
plt.grid(True)
plt.legend(loc=0)
plt.show()
